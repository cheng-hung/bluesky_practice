# %%
from diffpy.pdfgetx.pdfconfig import PDFConfig, loadPDFConfig
from diffpy.pdfgetx.pdfgetter import PDFGetter
from diffpy.pdfgetx.transformation import Transformation
from diffpy.pdfgetx.functs import loaddata, findfiles

# %%
from pdfstream.io import load_array
from pdfstream.transformation.io import load_pdfconfig, write_pdfgetter
from pdfstream.transformation.main import get_pdf
from diffpy.pdfgetx import PDFConfig
from diffpy.pdfgetx.pdfgetter import PDFConfigError
import typing
# Out:
# /opt/miniconda3/envs/pdfstream_310/lib/python3.10/site-packages/pdfstream/data.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib widget

# %%
import diffpy.pdfgetx.pdfgetxapplication as dipp

# %%
dipp.PDFGetXApplication?
# Out:
# Init signature: dipp.PDFGetXApplication(name)
# Docstring:
# The runner class for command line programs pdfgetx3, pdfgetn3.
#
# Attributes
# ----------
# name : str
#     The application name which can be "pdfgetx3" or "pdfgetn3".
#     This controls the default `config.mode` value and the names
#     of default configuration files.
# config : PDFConfig
#     The configuration for PDF processing.
# pdfgetter : PDFGetter
#     The PDF extraction object used in this application.
# File:           /opt/miniconda3/envs/pdfstream_310/lib/python3.10/site-packages/diffpy.pdfgetx-2.2.1/diffpy/pdfgetx3.10/pdfgetxapplication.py
# Type:           type
# Subclasses:

# %%
dipp.PDFGetXApplication.tuneconfig?
# Out:
# Signature:
# dipp.PDFGetXApplication.tuneconfig(
#     self,
#     plotids=None,
#     pdfgetter=None,
#     axeslist=None,
# )
# Docstring:
# Open a GUI window for interactive tuning of configuration variables.
# This creates dynamic plots according to the config.plot parameter.
#
# plotids      -- string or iterable that specify what interactive plots
#                 should be tuned.  By default the same as config.plot.
#                 Can be also an integer index or name of a transformation
#                 in pdfgetter or a reference to a Transformation object.
#                 For more details see documentation for the TuneConfig
#                 class in diffpy.pdfgetx.tuneconfig.
# pdfgetter    -- optional argument for a PDFGetter object to be tuned.
#                 This is by default the active pdfgetter.
# axeslist     -- optional list of matplotlib Axes for displaying the
#                 interactive plots.  When None, use subplot(N, 1, i) to
# ...

# %%
chi_fn = 'Cs_000_Br_100_Pb_100_OLA_020_PF_018_Tol_1100_20250607-195546_91db25_scattering-1_mean_q.chi'
bkg_fn = 'Tol_OA_bkg_flow_10min_20250606-133729_88604c_mean.chi'
cfg_fn = 'pdfgetx3.cfg'

# %%
chi_array = load_array(chi_fn)
pdfconfig = load_pdfconfig(cfg_fn)
# Out:
# INFO:finished parsing config file
# INFO:diffpy.pdfgetx.user:finished parsing config file

# %%
pdfgetter = get_pdf(pdfconfig, chi_array)
# Out:
# INFO:configuring PDFGetter mode 'xray'
# INFO:diffpy.pdfgetx.user:configuring PDFGetter mode 'xray'
# INFO:calling config_xray
# INFO:diffpy.pdfgetx.user:calling config_xray
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
getxApp = dipp.PDFGetXApplication("pdfgetx3")

# %%
getxApp.tuneconfig(pdfgetter=pdfgetter)
# Out:
# INFO:resolving plotmethods from plotids = None
# INFO:diffpy.pdfgetx.user:resolving plotmethods from plotids = None
# INFO:found 4 linked plots
# INFO:diffpy.pdfgetx.user:found 4 linked plots
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
